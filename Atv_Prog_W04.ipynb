# %% [markdown]
# ###**Descrição da ponderada:**
#
# Objetivo: Otimizar um modelo de rede neural pré-treinado para detecção de fraudes em cartões de crédito. Aplicar técnicas avançadas de ajuste fino de hiperparâmetros, como grid search e random search, com o objetivo de aprimorar as métricas de desempenho do modelo, incluindo precisão, recall, F1-score e AUC-ROC. A atividade também exige uma comparação entre o modelo otimizado e o modelo original, permitindo avaliar o impacto das modificações nos hiperparâmetros sobre o desempenho geral.

# %%
# %pip install gdown
import gdown
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.12/dist-packages (5.2.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from gdown) (4.13.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from gdown) (3.19.1)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.12/dist-packages (from gdown) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from gdown) (4.67.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (2025.8.3)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (1.7.1)

# %%
arquivo_destino_colab = "dataset.csv"
doc_id = "1u_OWAPkIdgJw1ah5xP_dGBFMSANxjxEl"
URL = f"https://drive.google.com/uc?id={doc_id}"
gdown.download(URL, arquivo_destino_colab, quiet=False)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1u_OWAPkIdgJw1ah5xP_dGBFMSANxjxEl
# From (redirected): https://drive.google.com/uc?id=1u_OWAPkIdgJw1ah5xP_dGBFMSANxjxEl&confirm=t&uuid=80b1c8df-893d-4b78-bc85-7f651946f5c6
# To: /content/dataset.csv
# 100%|██████████| 151M/151M [00:05<00:00, 25.7MB/s]
# 'dataset.csv'

# %% [markdown]
# ## Instalação e imports

# %%
# !pip -q install scikeras imbalanced-learn --upgrade

import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split, StratifiedKFold, RandomizedSearchCV, GridSearchCV
from sklearn.metrics import (
    classification_report, confusion_matrix, roc_auc_score, roc_curve, precision_recall_curve,
    precision_score, recall_score, f1_score
)
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer, make_column_selector
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.utils.class_weight import compute_class_weight

from scikeras.wrappers import KerasClassifier

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, regularizers

SEED = 42
np.random.seed(SEED)
tf.random.set_seed(SEED)

print("TensorFlow:", tf.__version__)
# Out:
# TensorFlow: 2.19.0

# %%
df = pd.read_csv("dataset.csv")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
df.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %% [markdown]
# Daqui pra frente é o pré processamento ...

# %% [markdown]
# ## Preparação de features

# %%
# Alvo dataset:
target_col = "Class"
assert target_col in df.columns, f"Coluna-alvo '{target_col}' não encontrada. Colunas: {df.columns.tolist()}"

# Remover colunas pouco úteis ou não normalizadas que atrapalham (Time)
drop_cols = [c for c in ["Time"] if c in df.columns]

X = df.drop(columns=[target_col] + drop_cols, errors="ignore")
y = df[target_col].astype(int)

# Sanidade: para o alvo binário
assert set(np.unique(y)).issubset({0, 1}), "A coluna alvo precisa ser binária (0/1)."

# Split estratificado
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=SEED
)

# Pesos de classe para desbalanceamento
classes = np.array([0, 1])
class_weights_values = compute_class_weight(
    class_weight="balanced", classes=classes, y=y_train
)
CLASS_WEIGHT = {int(k): float(v) for k, v in zip(classes, class_weights_values)}
print("Class weights:", CLASS_WEIGHT)

# Kwargs de treino
FIT_KW = {
    "clf__validation_split": 0.1,
    "clf__class_weight": CLASS_WEIGHT,
}
# Out:
# Class weights: {0: 0.5008661206149896, 1: 289.14340101522845}

# %%
# Pré-processamento: imputação + padronização das features numéricas
numeric_selector = make_column_selector(dtype_include=np.number)

preprocess = ColumnTransformer(
    transformers=[
        ("num", Pipeline([
            ("imputer", SimpleImputer(strategy="median")),
            ("scaler", StandardScaler()),
        ]), numeric_selector),
    ],
    remainder="drop"
)

def build_mlp(meta,
              hidden_layers=2,
              units=64,
              dropout=0.2,
              l2=1e-4,
              learning_rate=1e-3):
    """Usa 'meta' do SciKeras para obter n_features após o preprocess."""
    input_dim = meta["n_features_in_"]
    model = keras.Sequential(name="mlp_fraud")
    model.add(layers.Input(shape=(input_dim,)))
    for _ in range(hidden_layers):
        model.add(layers.Dense(units, activation="relu",
                               kernel_regularizer=regularizers.l2(l2)))
        model.add(layers.BatchNormalization())
        if dropout and dropout > 0:
            model.add(layers.Dropout(dropout))
    model.add(layers.Dense(1, activation="sigmoid"))

    opt = keras.optimizers.Adam(learning_rate=learning_rate)
    model.compile(
        optimizer=opt,
        loss="binary_crossentropy",
        metrics=[keras.metrics.AUC(name="auc"),
                 keras.metrics.Precision(name="prec"),
                 keras.metrics.Recall(name="rec")]
    )
    return model

early_stop = keras.callbacks.EarlyStopping(
    monitor="val_auc", patience=5, mode="max", restore_best_weights=True
)
reduce_lr = keras.callbacks.ReduceLROnPlateau(
    monitor="val_auc", factor=0.5, patience=3, mode="max", min_lr=1e-6
)

baseline_clf = KerasClassifier(
    model=build_mlp,
    # hiperparâmetros baseline:
    model__hidden_layers=2,
    model__units=64,
    model__dropout=0.2,
    model__l2=1e-4,
    model__learning_rate=1e-3,
    epochs=30,
    batch_size=512,
    verbose=0,
    callbacks=[early_stop, reduce_lr],
)

baseline_pipe = Pipeline([
    ("preprocess", preprocess),
    ("clf", baseline_clf),
])

# %% [markdown]
# ## Modelo baseline (MLP) + avaliação

# %%
# Treino baseline
baseline_pipe.fit(X_train, y_train, **FIT_KW)

# Avaliação
def proba_pos(p):
    p = np.asarray(p)
    if p.ndim == 2 and p.shape[1] == 2:
        return p[:, 1]
    return p.ravel()

def evaluate(pipe, X, y, name="model"):
    # Tentativa padrão via Pipeline.predict_proba
    try:
        y_proba = proba_pos(pipe.predict_proba(X))
    except Exception as e:
        # Fallback: transforma manualmente e usa o estimador final
        try:
            Xt = pipe.named_steps["preprocess"].transform(X)
            y_proba = proba_pos(pipe.named_steps["clf"].predict_proba(Xt))
            print(f"[Aviso] Fallback do predict_proba do Pipeline → estimador direto ({type(e).__name__}: {e})")
        except Exception as e2:
            raise e2  # re-levanta se nem o fallback funcionar

    y_pred  = (y_proba >= 0.5).astype(int)

    auc  = roc_auc_score(y, y_proba)
    pre  = precision_score(y, y_pred, zero_division=0)
    rec  = recall_score(y, y_pred, zero_division=0)
    f1   = f1_score(y, y_pred, zero_division=0)
    cm   = confusion_matrix(y, y_pred)

    print(f"\n=== {name} ===")
    print(f"AUC-ROC : {auc:.4f}")
    print(f"Precisão: {pre:.4f}")
    print(f"Recall  : {rec:.4f}")
    print(f"F1-score: {f1:.4f}")
    print("\nMatriz de confusão (verdadeiro x predito):\n", cm)
    print("\nRelatório de classificação:\n", classification_report(y, y_pred, digits=4, zero_division=0))

    fpr, tpr, _ = roc_curve(y, y_proba)
    prec, rec_, _ = precision_recall_curve(y, y_proba)

    plt.figure()
    plt.plot(fpr, tpr, label=f"{name} (AUC={auc:.3f})")
    plt.plot([0,1], [0,1], linestyle="--")
    plt.xlabel("FPR")
    plt.ylabel("TPR")
    plt.title(f"ROC - {name}")
    plt.legend(loc="lower right")
    plt.show()

    plt.figure()
    plt.plot(rec_, prec, label=f"{name}")
    plt.xlabel("Recall")
    plt.ylabel("Precisão")
    plt.title(f"Precision-Recall - {name}")
    plt.legend(loc="lower left")
    plt.show()

    return {"model": name, "auc": auc, "precision": pre, "recall": rec, "f1": f1}

# %%
baseline_metrics = evaluate(baseline_pipe, X_test, y_test, name="Baseline")
# Out:
# [Aviso] Fallback do predict_proba do Pipeline → estimador direto (AttributeError: 'super' object has no attribute '__sklearn_tags__')
#
# === Baseline ===
# AUC-ROC : 0.9761
# Precisão: 0.0509
# Recall  : 0.9082
# F1-score: 0.0964
#
# Matriz de confusão (verdadeiro x predito):
#  [[55204  1660]
#  [    9    89]]
#
# Relatório de classificação:
#                precision    recall  f1-score   support
#
#            0     0.9998    0.9708    0.9851     56864
#            1     0.0509    0.9082    0.0964        98
#
#     accuracy                         0.9707     56962
#    macro avg     0.5254    0.9395    0.5407     56962
# weighted avg     0.9982    0.9707    0.9836     56962

# %% [markdown]
# ## Interpretação dos resultados
#
# * **AUC-ROC = 0,9761 (alta)**
#   O modelo ranqueia muito bem as transações: em média, coloca as fraudes acima das não-fraudes. A curva ROC perto do canto superior-esquerdo confirma isso.
# * **Recall = 0,9082 (muito alto)**
#   Ele encontra **89 de 98** fraudes no teste. Só **9** passam batidas (FN).
# * **Precisão = 0,0509 (muito baixa)**
#   De cada 100 alertas, **\~5** são fraudes de verdade. Há **1.660 falsos positivos (FP)** contra **89 verdadeiros positivos (TP)**.
#   Isso acontece porque a **base é extremamente desbalanceada** (fraude ≈ **0,17%** no teste: 98/56.962). Mesmo um **FPR pequeno (\~2,92%)** vira muitos FP.
# * **F1 = 0,0964 (baixo)**
#   F1 cai porque a precisão é muito baixa (F1 sendo o “meio-termo” entre precisão e recall).
# * **Acurácia = 0,9707 (enganosa)**
#   Em bases tão desbalanceadas, como é o caso aqui, acurácia não é útil: um modelo “sempre 0” teria **\~99,83%** de acurácia aqui — e ainda assim não detectaria nenhuma fraude.
#
# ## Confusão em números
#
# * **TN = 55.204** | **FP = 1.660** → **FPR ≈ 2,92%**
# * **FN = 9** | **TP = 89** → **Recall ≈ 90,82%**
# * Só que **Precisão = 89 / (89 + 1.660) ≈ 5,09%**
#
# ## Curvas
#
# * **ROC alta**: separabilidade boa (AUC \~0,976).
# * **Precision-Recall**: cai conforme se busca mais recall.
#   No threshold padrão (0,5), o modelo está numa região de **recall alto** com **precisão muito baixa**; subir o threshold pode melhorar a precisão mas diminui recall (trade-off).
#
# ## Conclusão do baseline
#
# * O modelo está bem calibrado para **capturar fraudes** (recall alto) **à custa de muitos falsos positivos**, o que dilui a precisão.
# * Isso não é um erro do modelo, e sim uma consequência do **desbalanceamento** da base e do **threshold** escolhido.

# %% [markdown]
# ## Random Search

# %%
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import StratifiedShuffleSplit

def _safe_predict_proba_from_pipeline(pipeline, X):
    """Tenta pipeline.predict_proba; se falhar, aplica preprocess e chama o clf.predict_proba."""
    try:
        proba = pipeline.predict_proba(X)
    except Exception:
        Xt = pipeline.named_steps["preprocess"].transform(X)
        proba = pipeline.named_steps["clf"].predict_proba(Xt)
    proba = np.asarray(proba)
    return proba[:, 1] if proba.ndim == 2 and proba.shape[1] == 2 else proba.ravel()

def safe_auc_scorer(estimator, X, y):
    """Scorer de AUC robusto para CV com SciKeras + Pipeline."""
    y_proba = _safe_predict_proba_from_pipeline(estimator, X)
    return roc_auc_score(y, y_proba)

def stratified_subsample(X, y, max_samples=60000, random_state=42):
    """Retorna um subset estratificado de até max_samples sem quebrar a proporção das classes."""
    n = len(y)
    if n <= max_samples:
        return X, y
    frac = max_samples / n
    sss = StratifiedShuffleSplit(n_splits=1, train_size=frac, random_state=random_state)
    idx, _ = next(sss.split(np.zeros(n), y))
    return X.iloc[idx], y.iloc[idx]

# %%
from scipy.stats import loguniform, randint
from sklearn.model_selection import StratifiedKFold, RandomizedSearchCV
from scikeras.wrappers import KerasClassifier
from sklearn.pipeline import Pipeline
import tensorflow as tf
_
# subset para acelerar a busca (com o dataset inteiro não estava rodando)
MAX_SAMPLES_FOR_SEARCH = 60000
X_rs, y_rs = stratified_subsample(X_train, y_train, max_samples=MAX_SAMPLES_FOR_SEARCH, random_state=SEED)

early_stop_search = keras.callbacks.EarlyStopping(
    monitor="val_auc", patience=2, mode="max", restore_best_weights=True, min_delta=1e-4
)
reduce_lr_search = keras.callbacks.ReduceLROnPlateau(
    monitor="val_auc", factor=0.5, patience=1, mode="max", min_lr=1e-6
)

# estimador + pipeline
base_clf = KerasClassifier(
    model=build_mlp,
    callbacks=[early_stop_search, reduce_lr_search],
)

pipe_rs = Pipeline([
    ("preprocess", preprocess),
    ("clf", base_clf),
])

param_distributions = {
    "clf__model__hidden_layers": randint(1, 4),      # 1..3
    "clf__model__units": randint(32, 129),           # 32..128
    "clf__model__dropout": [0.0, 0.1, 0.2, 0.3, 0.4],
    "clf__model__l2": [0.0, 1e-5, 1e-4, 1e-3],
    "clf__model__learning_rate": loguniform(3e-5, 3e-3),
    "clf__batch_size": [512, 1024],
    "clf__epochs": [15, 20],
}

# CV curto p/ velocidade
cv = StratifiedKFold(n_splits=2, shuffle=True, random_state=SEED)

rs = RandomizedSearchCV(
    estimator=pipe_rs,
    param_distributions=param_distributions,
    n_iter=10,
    scoring=safe_auc_scorer,
    refit=True,
    cv=cv,
    verbose=1,
    n_jobs=1,
    random_state=SEED,
)

rs.fit(X_rs, y_rs, **{**FIT_KW, "clf__validation_split": 0.1})

print("\n=== Random Search: melhores hiperparâmetros ===")
print(rs.best_params_)
print(f"Melhor AUC-ROC (CV, subset): {rs.best_score_:.4f}")
# Out:
# Fitting 2 folds for each of 10 candidates, totalling 20 fits
# Epoch 1/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 13s 118ms/step - auc: 0.6348 - loss: 1.5178 - prec: 0.0023 - rec: 0.6447 - val_auc: 0.9935 - val_loss: 0.6786 - val_prec: 0.0063 - val_rec: 1.0000 - learning_rate: 0.0011
# Epoch 2/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.8774 - loss: 0.5185 - prec: 0.0037 - rec: 0.8646 - val_auc: 0.9963 - val_loss: 0.5029 - val_prec: 0.0210 - val_rec: 1.0000 - learning_rate: 0.0011
# Epoch 3/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.9115 - loss: 0.4614 - prec: 0.0049 - rec: 0.8986 - val_auc: 0.9980 - val_loss: 0.3703 - val_prec: 0.0526 - val_rec: 1.0000 - learning_rate: 0.0011
# Epoch 4/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - auc: 0.9526 - loss: 0.3536 - prec: 0.0064 - rec: 0.9354 - val_auc: 0.9986 - val_loss: 0.2881 - val_prec: 0.0750 - val_rec: 1.0000 - learning_rate: 0.0011
# Epoch 5/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9008 - loss: 0.3935 - prec: 0.0075 - rec: 0.8898 - val_auc: 0.9989 - val_loss: 0.2362 - val_prec: 0.0896 - val_rec: 1.0000 - learning_rate: 0.0011
# Epoch 6/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9455 - loss: 0.3056 - prec: 0.0093 - rec: 0.9080 - val_auc: 0.9989 - val_loss: 0.2092 - val_prec: 0.0723 - val_rec: 1.0000 - learning_rate: 0.0011
# Epoch 7/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9696 - loss: 0.2573 - prec: 0.0114 - rec: 0.9725 - val_auc: 0.9991 - val_loss: 0.1976 - val_prec: 0.0759 - val_rec: 1.0000 - learning_rate: 5.4384e-04
# Epoch 8/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9570 - loss: 0.2647 - prec: 0.0121 - rec: 0.9607 - val_auc: 0.9991 - val_loss: 0.1805 - val_prec: 0.0811 - val_rec: 1.0000 - learning_rate: 5.4384e-04
# Epoch 9/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9714 - loss: 0.2305 - prec: 0.0132 - rec: 0.9725 - val_auc: 0.9991 - val_loss: 0.1752 - val_prec: 0.0870 - val_rec: 1.0000 - learning_rate: 2.7192e-04
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Epoch 1/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 13s 145ms/step - auc: 0.4581 - loss: 3.4752 - prec: 0.0015 - rec: 0.4736 - val_auc: 0.9646 - val_loss: 0.7649 - val_prec: 0.0044 - val_rec: 1.0000 - learning_rate: 0.0011
# Epoch 2/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.8360 - loss: 0.6713 - prec: 0.0031 - rec: 0.8736 - val_auc: 0.9781 - val_loss: 0.6785 - val_prec: 0.0072 - val_rec: 1.0000 - learning_rate: 0.0011
# Epoch 3/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8904 - loss: 0.5505 - prec: 0.0039 - rec: 0.8664 - val_auc: 0.9822 - val_loss: 0.5367 - val_prec: 0.0152 - val_rec: 1.0000 - learning_rate: 0.0011
# Epoch 4/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9183 - loss: 0.4620 - prec: 0.0052 - rec: 0.9268 - val_auc: 0.9827 - val_loss: 0.4338 - val_prec: 0.0224 - val_rec: 0.8750 - learning_rate: 0.0011
# Epoch 5/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9556 - loss: 0.3612 - prec: 0.0065 - rec: 0.9480 - val_auc: 0.9812 - val_loss: 0.3606 - val_prec: 0.0345 - val_rec: 0.8750 - learning_rate: 0.0011
# Epoch 6/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9512 - loss: 0.3403 - prec: 0.0079 - rec: 0.9261 - val_auc: 0.9812 - val_loss: 0.3341 - val_prec: 0.0409 - val_rec: 0.8750 - learning_rate: 5.4384e-04
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 1/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 13s 121ms/step - auc: 0.5447 - loss: 1.1460 - prec: 0.0017 - rec: 0.5726 - val_auc: 0.7151 - val_loss: 0.7548 - val_prec: 0.0021 - val_rec: 0.6667 - learning_rate: 2.4867e-04
# Epoch 2/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.7363 - loss: 0.6655 - prec: 0.0024 - rec: 0.7417 - val_auc: 0.9240 - val_loss: 0.7470 - val_prec: 0.0036 - val_rec: 1.0000 - learning_rate: 2.4867e-04
# Epoch 3/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.8491 - loss: 0.5425 - prec: 0.0031 - rec: 0.9217 - val_auc: 0.9843 - val_loss: 0.7090 - val_prec: 0.0045 - val_rec: 1.0000 - learning_rate: 2.4867e-04
# Epoch 4/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8464 - loss: 0.5110 - prec: 0.0031 - rec: 0.8629 - val_auc: 0.9923 - val_loss: 0.6624 - val_prec: 0.0055 - val_rec: 1.0000 - learning_rate: 2.4867e-04
# Epoch 5/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9102 - loss: 0.4579 - prec: 0.0038 - rec: 0.9611 - val_auc: 0.9967 - val_loss: 0.6187 - val_prec: 0.0069 - val_rec: 1.0000 - learning_rate: 2.4867e-04
# Epoch 6/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9584 - loss: 0.4001 - prec: 0.0042 - rec: 0.9655 - val_auc: 0.9968 - val_loss: 0.5796 - val_prec: 0.0083 - val_rec: 1.0000 - learning_rate: 2.4867e-04
# Epoch 7/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9539 - loss: 0.3872 - prec: 0.0046 - rec: 0.9583 - val_auc: 0.9972 - val_loss: 0.5429 - val_prec: 0.0102 - val_rec: 1.0000 - learning_rate: 2.4867e-04
# Epoch 8/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9352 - loss: 0.3942 - prec: 0.0048 - rec: 0.9074 - val_auc: 0.9978 - val_loss: 0.5098 - val_prec: 0.0121 - val_rec: 1.0000 - learning_rate: 2.4867e-04
# Epoch 9/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9615 - loss: 0.3480 - prec: 0.0057 - rec: 0.9725 - val_auc: 0.9979 - val_loss: 0.4817 - val_prec: 0.0146 - val_rec: 1.0000 - learning_rate: 2.4867e-04
# Epoch 10/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9628 - loss: 0.3280 - prec: 0.0064 - rec: 0.9697 - val_auc: 0.9980 - val_loss: 0.4494 - val_prec: 0.0179 - val_rec: 1.0000 - learning_rate: 2.4867e-04
# Epoch 11/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9730 - loss: 0.3028 - prec: 0.0070 - rec: 0.9725 - val_auc: 0.9981 - val_loss: 0.4376 - val_prec: 0.0190 - val_rec: 1.0000 - learning_rate: 1.2433e-04
# Epoch 12/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9611 - loss: 0.3131 - prec: 0.0076 - rec: 0.9648 - val_auc: 0.9982 - val_loss: 0.4256 - val_prec: 0.0208 - val_rec: 1.0000 - learning_rate: 1.2433e-04
# Epoch 13/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9659 - loss: 0.3002 - prec: 0.0078 - rec: 0.9696 - val_auc: 0.9983 - val_loss: 0.4132 - val_prec: 0.0228 - val_rec: 1.0000 - learning_rate: 1.2433e-04
# Epoch 14/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - auc: 0.9158 - loss: 0.3615 - prec: 0.0077 - rec: 0.8976 - val_auc: 0.9988 - val_loss: 0.4005 - val_prec: 0.0246 - val_rec: 1.0000 - learning_rate: 1.2433e-04
# Epoch 15/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - auc: 0.9655 - loss: 0.2885 - prec: 0.0083 - rec: 0.9466 - val_auc: 0.9989 - val_loss: 0.3883 - val_prec: 0.0260 - val_rec: 1.0000 - learning_rate: 1.2433e-04
# Epoch 16/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - auc: 0.9708 - loss: 0.2690 - prec: 0.0088 - rec: 0.9725 - val_auc: 0.9989 - val_loss: 0.3833 - val_prec: 0.0271 - val_rec: 1.0000 - learning_rate: 6.2167e-05
# Epoch 17/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - auc: 0.9691 - loss: 0.2759 - prec: 0.0090 - rec: 0.9609 - val_auc: 0.9990 - val_loss: 0.3776 - val_prec: 0.0284 - val_rec: 1.0000 - learning_rate: 6.2167e-05
# Epoch 18/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.9577 - loss: 0.2967 - prec: 0.0095 - rec: 0.9725 - val_auc: 0.9990 - val_loss: 0.3728 - val_prec: 0.0296 - val_rec: 1.0000 - learning_rate: 6.2167e-05
# Epoch 19/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.9749 - loss: 0.2595 - prec: 0.0094 - rec: 0.9725 - val_auc: 0.9990 - val_loss: 0.3705 - val_prec: 0.0305 - val_rec: 1.0000 - learning_rate: 3.1083e-05
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 1/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 12s 116ms/step - auc: 0.4032 - loss: 1.7970 - prec: 0.0016 - rec: 0.4167 - val_auc: 0.9792 - val_loss: 0.7592 - val_prec: 0.0054 - val_rec: 1.0000 - learning_rate: 2.4867e-04
# Epoch 2/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - auc: 0.7361 - loss: 0.7297 - prec: 0.0029 - rec: 0.7499 - val_auc: 0.9747 - val_loss: 0.6776 - val_prec: 0.0086 - val_rec: 1.0000 - learning_rate: 2.4867e-04
# Epoch 3/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8620 - loss: 0.5963 - prec: 0.0036 - rec: 0.8999 - val_auc: 0.9685 - val_loss: 0.6438 - val_prec: 0.0101 - val_rec: 1.0000 - learning_rate: 1.2433e-04
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Epoch 1/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 11s 114ms/step - auc: 0.4682 - loss: 1.2950 - prec: 0.0015 - rec: 0.4427 - val_auc: 0.9863 - val_loss: 0.6520 - val_prec: 0.0231 - val_rec: 1.0000 - learning_rate: 0.0014
# Epoch 2/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - auc: 0.8308 - loss: 0.6917 - prec: 0.0035 - rec: 0.8149 - val_auc: 0.9976 - val_loss: 0.4747 - val_prec: 0.0732 - val_rec: 1.0000 - learning_rate: 0.0014
# Epoch 3/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9590 - loss: 0.4408 - prec: 0.0060 - rec: 0.9623 - val_auc: 0.9963 - val_loss: 0.3539 - val_prec: 0.1389 - val_rec: 0.8333 - learning_rate: 0.0014
# Epoch 4/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9055 - loss: 0.4631 - prec: 0.0080 - rec: 0.8816 - val_auc: 0.9989 - val_loss: 0.3243 - val_prec: 0.1200 - val_rec: 1.0000 - learning_rate: 6.9339e-04
# Epoch 5/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9662 - loss: 0.3514 - prec: 0.0099 - rec: 0.9592 - val_auc: 0.9992 - val_loss: 0.3012 - val_prec: 0.1154 - val_rec: 1.0000 - learning_rate: 6.9339e-04
# Epoch 6/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9576 - loss: 0.3391 - prec: 0.0118 - rec: 0.9454 - val_auc: 0.9987 - val_loss: 0.2766 - val_prec: 0.1463 - val_rec: 1.0000 - learning_rate: 6.9339e-04
# Epoch 7/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9519 - loss: 0.3428 - prec: 0.0129 - rec: 0.9208 - val_auc: 0.9991 - val_loss: 0.2706 - val_prec: 0.1250 - val_rec: 1.0000 - learning_rate: 3.4669e-04
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Epoch 1/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 13s 147ms/step - auc: 0.8579 - loss: 0.6534 - prec: 0.0034 - rec: 0.8507 - val_auc: 0.9905 - val_loss: 0.5966 - val_prec: 0.0389 - val_rec: 0.8750 - learning_rate: 0.0014
# Epoch 2/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - auc: 0.9751 - loss: 0.4304 - prec: 0.0063 - rec: 0.9588 - val_auc: 0.9949 - val_loss: 0.4318 - val_prec: 0.1148 - val_rec: 0.8750 - learning_rate: 0.0014
# Epoch 3/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - auc: 0.9926 - loss: 0.3387 - prec: 0.0114 - rec: 0.9962 - val_auc: 0.9972 - val_loss: 0.3248 - val_prec: 0.1892 - val_rec: 0.8750 - learning_rate: 0.0014
# Epoch 4/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - auc: 0.9571 - loss: 0.3571 - prec: 0.0169 - rec: 0.9467 - val_auc: 0.9962 - val_loss: 0.2668 - val_prec: 0.1667 - val_rec: 0.8750 - learning_rate: 0.0014
# Epoch 5/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - auc: 0.9784 - loss: 0.3037 - prec: 0.0228 - rec: 0.9376 - val_auc: 0.9960 - val_loss: 0.2519 - val_prec: 0.1400 - val_rec: 0.8750 - learning_rate: 6.9339e-04
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 1/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 182ms/step - auc: 0.4423 - loss: 3.0867 - prec: 0.0013 - rec: 0.4378 - val_auc: 0.1754 - val_loss: 0.6610 - val_prec: 8.7336e-04 - val_rec: 0.1667 - learning_rate: 1.2179e-04
# Epoch 2/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - auc: 0.4138 - loss: 2.3757 - prec: 0.0013 - rec: 0.4379 - val_auc: 0.1889 - val_loss: 0.6826 - val_prec: 8.2169e-04 - val_rec: 0.1667 - learning_rate: 1.2179e-04
# Epoch 3/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc: 0.4976 - loss: 1.7954 - prec: 0.0014 - rec: 0.4737 - val_auc: 0.2393 - val_loss: 0.7006 - val_prec: 7.7821e-04 - val_rec: 0.1667 - learning_rate: 1.2179e-04
# Epoch 4/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - auc: 0.5293 - loss: 1.8284 - prec: 0.0017 - rec: 0.5433 - val_auc: 0.3905 - val_loss: 0.7161 - val_prec: 0.0015 - val_rec: 0.3333 - learning_rate: 1.2179e-04
# Epoch 5/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - auc: 0.5381 - loss: 1.0320 - prec: 0.0017 - rec: 0.5361 - val_auc: 0.5711 - val_loss: 0.7288 - val_prec: 0.0022 - val_rec: 0.5000 - learning_rate: 1.2179e-04
# Epoch 6/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - auc: 0.6026 - loss: 1.5874 - prec: 0.0018 - rec: 0.5777 - val_auc: 0.8020 - val_loss: 0.7390 - val_prec: 0.0045 - val_rec: 1.0000 - learning_rate: 1.2179e-04
# Epoch 7/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - auc: 0.6820 - loss: 0.9874 - prec: 0.0021 - rec: 0.6708 - val_auc: 0.9186 - val_loss: 0.7465 - val_prec: 0.0044 - val_rec: 1.0000 - learning_rate: 1.2179e-04
# Epoch 8/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - auc: 0.7732 - loss: 0.6964 - prec: 0.0026 - rec: 0.8058 - val_auc: 0.9616 - val_loss: 0.7508 - val_prec: 0.0045 - val_rec: 1.0000 - learning_rate: 1.2179e-04
# Epoch 9/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc: 0.8960 - loss: 0.5851 - prec: 0.0029 - rec: 0.9275 - val_auc: 0.9764 - val_loss: 0.7523 - val_prec: 0.0045 - val_rec: 1.0000 - learning_rate: 1.2179e-04
# Epoch 10/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc: 0.6384 - loss: 0.9221 - prec: 0.0020 - rec: 0.6105 - val_auc: 0.9856 - val_loss: 0.7532 - val_prec: 0.0046 - val_rec: 1.0000 - learning_rate: 1.2179e-04
# Epoch 11/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.8604 - loss: 0.7043 - prec: 0.0028 - rec: 0.8750 - val_auc: 0.9899 - val_loss: 0.7519 - val_prec: 0.0046 - val_rec: 1.0000 - learning_rate: 1.2179e-04
# Epoch 12/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.8548 - loss: 0.7122 - prec: 0.0029 - rec: 0.8806 - val_auc: 0.9929 - val_loss: 0.7487 - val_prec: 0.0047 - val_rec: 1.0000 - learning_rate: 1.2179e-04
# Epoch 13/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9291 - loss: 0.4962 - prec: 0.0032 - rec: 0.9635 - val_auc: 0.9947 - val_loss: 0.7439 - val_prec: 0.0047 - val_rec: 1.0000 - learning_rate: 1.2179e-04
# Epoch 14/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9143 - loss: 0.4895 - prec: 0.0032 - rec: 0.9314 - val_auc: 0.9953 - val_loss: 0.7384 - val_prec: 0.0048 - val_rec: 1.0000 - learning_rate: 1.2179e-04
# Epoch 15/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9310 - loss: 0.5164 - prec: 0.0033 - rec: 0.9559 - val_auc: 0.9965 - val_loss: 0.7316 - val_prec: 0.0049 - val_rec: 1.0000 - learning_rate: 1.2179e-04
# Epoch 16/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9425 - loss: 0.5136 - prec: 0.0034 - rec: 0.9637 - val_auc: 0.9975 - val_loss: 0.7242 - val_prec: 0.0049 - val_rec: 1.0000 - learning_rate: 1.2179e-04
# Epoch 17/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.8472 - loss: 0.6685 - prec: 0.0030 - rec: 0.8551 - val_auc: 0.9979 - val_loss: 0.7167 - val_prec: 0.0050 - val_rec: 1.0000 - learning_rate: 1.2179e-04
# Epoch 18/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.9257 - loss: 0.4887 - prec: 0.0033 - rec: 0.9088 - val_auc: 0.9981 - val_loss: 0.7078 - val_prec: 0.0051 - val_rec: 1.0000 - learning_rate: 1.2179e-04
# Epoch 19/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9392 - loss: 0.5097 - prec: 0.0034 - rec: 0.9251 - val_auc: 0.9984 - val_loss: 0.6992 - val_prec: 0.0052 - val_rec: 1.0000 - learning_rate: 1.2179e-04
# Epoch 20/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.8955 - loss: 0.5621 - prec: 0.0034 - rec: 0.8971 - val_auc: 0.9989 - val_loss: 0.6904 - val_prec: 0.0054 - val_rec: 1.0000 - learning_rate: 1.2179e-04
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 1/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - auc: 0.8309 - loss: 0.6151 - prec: 0.0036 - rec: 0.8487 - val_auc: 0.9473 - val_loss: 1.2710 - val_prec: 0.0029 - val_rec: 1.0000 - learning_rate: 1.2179e-04
# Epoch 2/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - auc: 0.8592 - loss: 0.5941 - prec: 0.0036 - rec: 0.8649 - val_auc: 0.9512 - val_loss: 1.1606 - val_prec: 0.0032 - val_rec: 1.0000 - learning_rate: 1.2179e-04
# Epoch 3/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - auc: 0.8950 - loss: 0.5431 - prec: 0.0038 - rec: 0.8692 - val_auc: 0.9536 - val_loss: 1.0701 - val_prec: 0.0037 - val_rec: 1.0000 - learning_rate: 1.2179e-04
# Epoch 4/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc: 0.9036 - loss: 0.5258 - prec: 0.0040 - rec: 0.9123 - val_auc: 0.9561 - val_loss: 0.9961 - val_prec: 0.0043 - val_rec: 1.0000 - learning_rate: 1.2179e-04
# Epoch 5/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - auc: 0.7947 - loss: 0.6459 - prec: 0.0032 - rec: 0.7271 - val_auc: 0.9582 - val_loss: 0.9364 - val_prec: 0.0051 - val_rec: 1.0000 - learning_rate: 1.2179e-04
# Epoch 6/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - auc: 0.9053 - loss: 0.5155 - prec: 0.0041 - rec: 0.9069 - val_auc: 0.9604 - val_loss: 0.8884 - val_prec: 0.0057 - val_rec: 1.0000 - learning_rate: 1.2179e-04
# Epoch 7/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc: 0.9140 - loss: 0.4944 - prec: 0.0040 - rec: 0.8807 - val_auc: 0.9613 - val_loss: 0.8485 - val_prec: 0.0064 - val_rec: 1.0000 - learning_rate: 1.2179e-04
# Epoch 8/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - auc: 0.9230 - loss: 0.4860 - prec: 0.0043 - rec: 0.9053 - val_auc: 0.9627 - val_loss: 0.8151 - val_prec: 0.0070 - val_rec: 1.0000 - learning_rate: 1.2179e-04
# Epoch 9/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc: 0.9578 - loss: 0.4433 - prec: 0.0047 - rec: 0.9788 - val_auc: 0.9637 - val_loss: 0.7862 - val_prec: 0.0077 - val_rec: 1.0000 - learning_rate: 1.2179e-04
# Epoch 10/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - auc: 0.9084 - loss: 0.4804 - prec: 0.0043 - rec: 0.8819 - val_auc: 0.9644 - val_loss: 0.7610 - val_prec: 0.0080 - val_rec: 1.0000 - learning_rate: 1.2179e-04
# Epoch 11/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.9376 - loss: 0.4515 - prec: 0.0048 - rec: 0.9526 - val_auc: 0.9661 - val_loss: 0.7386 - val_prec: 0.0085 - val_rec: 1.0000 - learning_rate: 1.2179e-04
# Epoch 12/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9236 - loss: 0.4645 - prec: 0.0047 - rec: 0.9281 - val_auc: 0.9669 - val_loss: 0.7190 - val_prec: 0.0091 - val_rec: 1.0000 - learning_rate: 1.2179e-04
# Epoch 13/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.9344 - loss: 0.4465 - prec: 0.0048 - rec: 0.9192 - val_auc: 0.9678 - val_loss: 0.7017 - val_prec: 0.0096 - val_rec: 1.0000 - learning_rate: 1.2179e-04
# Epoch 14/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9037 - loss: 0.4606 - prec: 0.0045 - rec: 0.8592 - val_auc: 0.9695 - val_loss: 0.6853 - val_prec: 0.0100 - val_rec: 1.0000 - learning_rate: 1.2179e-04
# Epoch 15/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9476 - loss: 0.4140 - prec: 0.0052 - rec: 0.9387 - val_auc: 0.9712 - val_loss: 0.6706 - val_prec: 0.0104 - val_rec: 1.0000 - learning_rate: 1.2179e-04
# Epoch 16/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - auc: 0.9433 - loss: 0.4146 - prec: 0.0051 - rec: 0.9192 - val_auc: 0.9726 - val_loss: 0.6568 - val_prec: 0.0110 - val_rec: 1.0000 - learning_rate: 1.2179e-04
# Epoch 17/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9426 - loss: 0.4082 - prec: 0.0053 - rec: 0.9304 - val_auc: 0.9738 - val_loss: 0.6436 - val_prec: 0.0114 - val_rec: 1.0000 - learning_rate: 1.2179e-04
# Epoch 18/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - auc: 0.9605 - loss: 0.3936 - prec: 0.0057 - rec: 0.9877 - val_auc: 0.9743 - val_loss: 0.6306 - val_prec: 0.0120 - val_rec: 1.0000 - learning_rate: 1.2179e-04
# Epoch 19/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9603 - loss: 0.3820 - prec: 0.0055 - rec: 0.9222 - val_auc: 0.9757 - val_loss: 0.6180 - val_prec: 0.0125 - val_rec: 1.0000 - learning_rate: 1.2179e-04
# Epoch 20/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - auc: 0.9424 - loss: 0.3913 - prec: 0.0058 - rec: 0.9345 - val_auc: 0.9759 - val_loss: 0.6063 - val_prec: 0.0130 - val_rec: 1.0000 - learning_rate: 1.2179e-04
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 1/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 7s 84ms/step - auc: 0.9375 - loss: 0.4373 - prec: 0.0037 - rec: 0.9538 - val_auc: 0.9989 - val_loss: 0.6957 - val_prec: 0.0050 - val_rec: 1.0000 - learning_rate: 5.0214e-04
# Epoch 2/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.9742 - loss: 0.3246 - prec: 0.0056 - rec: 0.9709 - val_auc: 0.9996 - val_loss: 0.5480 - val_prec: 0.0111 - val_rec: 1.0000 - learning_rate: 5.0214e-04
# Epoch 3/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - auc: 0.9769 - loss: 0.2658 - prec: 0.0088 - rec: 0.9709 - val_auc: 0.9998 - val_loss: 0.4377 - val_prec: 0.0248 - val_rec: 1.0000 - learning_rate: 5.0214e-04
# Epoch 4/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.9788 - loss: 0.2197 - prec: 0.0155 - rec: 0.9709 - val_auc: 0.9998 - val_loss: 0.3559 - val_prec: 0.0500 - val_rec: 1.0000 - learning_rate: 5.0214e-04
# Epoch 5/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.9799 - loss: 0.1871 - prec: 0.0258 - rec: 0.9725 - val_auc: 0.9999 - val_loss: 0.3211 - val_prec: 0.0690 - val_rec: 1.0000 - learning_rate: 2.5107e-04
# Epoch 6/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - auc: 0.9803 - loss: 0.1713 - prec: 0.0348 - rec: 0.9725 - val_auc: 0.9999 - val_loss: 0.2908 - val_prec: 0.0822 - val_rec: 1.0000 - learning_rate: 2.5107e-04
# Epoch 7/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9806 - loss: 0.1586 - prec: 0.0443 - rec: 0.9725 - val_auc: 0.9999 - val_loss: 0.2771 - val_prec: 0.0857 - val_rec: 1.0000 - learning_rate: 1.2554e-04
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Epoch 1/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - auc: 0.3479 - loss: 1.1855 - prec: 8.8204e-04 - rec: 0.2966 - val_auc: 0.9559 - val_loss: 0.5586 - val_prec: 0.0108 - val_rec: 0.8750 - learning_rate: 5.0214e-04
# Epoch 2/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9167 - loss: 0.4749 - prec: 0.0031 - rec: 0.9382 - val_auc: 0.9716 - val_loss: 0.5367 - val_prec: 0.0127 - val_rec: 0.8750 - learning_rate: 5.0214e-04
# Epoch 3/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9355 - loss: 0.4085 - prec: 0.0040 - rec: 0.9461 - val_auc: 0.9825 - val_loss: 0.5006 - val_prec: 0.0180 - val_rec: 1.0000 - learning_rate: 5.0214e-04
# Epoch 4/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9532 - loss: 0.3509 - prec: 0.0056 - rec: 0.9461 - val_auc: 0.9891 - val_loss: 0.4580 - val_prec: 0.0249 - val_rec: 1.0000 - learning_rate: 5.0214e-04
# Epoch 5/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9708 - loss: 0.3029 - prec: 0.0087 - rec: 0.9581 - val_auc: 0.9927 - val_loss: 0.4143 - val_prec: 0.0340 - val_rec: 1.0000 - learning_rate: 5.0214e-04
# Epoch 6/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9869 - loss: 0.2633 - prec: 0.0137 - rec: 0.9695 - val_auc: 0.9946 - val_loss: 0.3722 - val_prec: 0.0423 - val_rec: 1.0000 - learning_rate: 5.0214e-04
# Epoch 7/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9945 - loss: 0.2306 - prec: 0.0211 - rec: 0.9962 - val_auc: 0.9954 - val_loss: 0.3336 - val_prec: 0.0563 - val_rec: 1.0000 - learning_rate: 5.0214e-04
# Epoch 8/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9971 - loss: 0.2033 - prec: 0.0301 - rec: 0.9962 - val_auc: 0.9959 - val_loss: 0.2985 - val_prec: 0.0696 - val_rec: 1.0000 - learning_rate: 5.0214e-04
# Epoch 9/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9981 - loss: 0.1803 - prec: 0.0400 - rec: 1.0000 - val_auc: 0.9959 - val_loss: 0.2675 - val_prec: 0.0745 - val_rec: 0.8750 - learning_rate: 5.0214e-04
# Epoch 10/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9986 - loss: 0.1624 - prec: 0.0483 - rec: 1.0000 - val_auc: 0.9961 - val_loss: 0.2550 - val_prec: 0.0833 - val_rec: 0.8750 - learning_rate: 2.5107e-04
# Epoch 11/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9988 - loss: 0.1535 - prec: 0.0541 - rec: 1.0000 - val_auc: 0.9960 - val_loss: 0.2422 - val_prec: 0.0946 - val_rec: 0.8750 - learning_rate: 2.5107e-04
# Epoch 12/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9989 - loss: 0.1458 - prec: 0.0589 - rec: 1.0000 - val_auc: 0.9960 - val_loss: 0.2367 - val_prec: 0.0959 - val_rec: 0.8750 - learning_rate: 1.2554e-04
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 1/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 13s 242ms/step - auc: 0.2100 - loss: 2.3451 - prec: 5.2386e-04 - rec: 0.1722 - val_auc: 0.1635 - val_loss: 0.6899 - val_prec: 7.7160e-04 - val_rec: 0.1667 - learning_rate: 4.5534e-05
# Epoch 2/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.2903 - loss: 1.8188 - prec: 9.3308e-04 - rec: 0.3083 - val_auc: 0.1941 - val_loss: 0.7508 - val_prec: 4.6970e-04 - val_rec: 0.1667 - learning_rate: 4.5534e-05
# Epoch 3/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.2836 - loss: 1.8963 - prec: 8.1631e-04 - rec: 0.2695 - val_auc: 0.3670 - val_loss: 0.8008 - val_prec: 0.0013 - val_rec: 0.5000 - learning_rate: 4.5534e-05
# Epoch 4/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - auc: 0.4521 - loss: 1.6689 - prec: 0.0015 - rec: 0.5178 - val_auc: 0.6841 - val_loss: 0.8353 - val_prec: 0.0020 - val_rec: 0.8333 - learning_rate: 4.5534e-05
# Epoch 5/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.3768 - loss: 1.6439 - prec: 0.0011 - rec: 0.3677 - val_auc: 0.8115 - val_loss: 0.8553 - val_prec: 0.0020 - val_rec: 0.8333 - learning_rate: 4.5534e-05
# Epoch 6/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.4223 - loss: 1.3895 - prec: 0.0014 - rec: 0.4625 - val_auc: 0.8530 - val_loss: 0.8669 - val_prec: 0.0025 - val_rec: 1.0000 - learning_rate: 4.5534e-05
# Epoch 7/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.5744 - loss: 0.9173 - prec: 0.0018 - rec: 0.6085 - val_auc: 0.8737 - val_loss: 0.8711 - val_prec: 0.0026 - val_rec: 1.0000 - learning_rate: 4.5534e-05
# Epoch 8/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.6260 - loss: 0.9541 - prec: 0.0019 - rec: 0.6355 - val_auc: 0.8904 - val_loss: 0.8687 - val_prec: 0.0027 - val_rec: 1.0000 - learning_rate: 4.5534e-05
# Epoch 9/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.6159 - loss: 0.9135 - prec: 0.0020 - rec: 0.6679 - val_auc: 0.9037 - val_loss: 0.8628 - val_prec: 0.0028 - val_rec: 1.0000 - learning_rate: 4.5534e-05
# Epoch 10/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.7316 - loss: 0.8406 - prec: 0.0022 - rec: 0.7269 - val_auc: 0.9140 - val_loss: 0.8572 - val_prec: 0.0029 - val_rec: 1.0000 - learning_rate: 4.5534e-05
# Epoch 11/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.6669 - loss: 0.7832 - prec: 0.0023 - rec: 0.7235 - val_auc: 0.9223 - val_loss: 0.8481 - val_prec: 0.0031 - val_rec: 1.0000 - learning_rate: 4.5534e-05
# Epoch 12/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.7884 - loss: 0.7185 - prec: 0.0024 - rec: 0.7866 - val_auc: 0.9285 - val_loss: 0.8374 - val_prec: 0.0032 - val_rec: 1.0000 - learning_rate: 4.5534e-05
# Epoch 13/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.7791 - loss: 0.6796 - prec: 0.0024 - rec: 0.7480 - val_auc: 0.9397 - val_loss: 0.8292 - val_prec: 0.0033 - val_rec: 1.0000 - learning_rate: 4.5534e-05
# Epoch 14/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.7755 - loss: 0.8727 - prec: 0.0026 - rec: 0.8051 - val_auc: 0.9476 - val_loss: 0.8234 - val_prec: 0.0034 - val_rec: 1.0000 - learning_rate: 4.5534e-05
# Epoch 15/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.8606 - loss: 0.5419 - prec: 0.0029 - rec: 0.9178 - val_auc: 0.9523 - val_loss: 0.8190 - val_prec: 0.0035 - val_rec: 1.0000 - learning_rate: 4.5534e-05
# Epoch 16/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - auc: 0.8384 - loss: 0.8071 - prec: 0.0028 - rec: 0.8622 - val_auc: 0.9584 - val_loss: 0.8112 - val_prec: 0.0036 - val_rec: 1.0000 - learning_rate: 4.5534e-05
# Epoch 17/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.8580 - loss: 0.6127 - prec: 0.0030 - rec: 0.9147 - val_auc: 0.9631 - val_loss: 0.8035 - val_prec: 0.0037 - val_rec: 1.0000 - learning_rate: 4.5534e-05
# Epoch 18/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.9284 - loss: 0.4834 - prec: 0.0032 - rec: 0.9704 - val_auc: 0.9698 - val_loss: 0.7977 - val_prec: 0.0037 - val_rec: 1.0000 - learning_rate: 4.5534e-05
# Epoch 19/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.8813 - loss: 0.5835 - prec: 0.0029 - rec: 0.8700 - val_auc: 0.9729 - val_loss: 0.7913 - val_prec: 0.0038 - val_rec: 1.0000 - learning_rate: 4.5534e-05
# Epoch 20/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.7984 - loss: 0.6332 - prec: 0.0028 - rec: 0.8139 - val_auc: 0.9785 - val_loss: 0.7834 - val_prec: 0.0039 - val_rec: 1.0000 - learning_rate: 4.5534e-05
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 1/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 12s 195ms/step - auc: 0.4118 - loss: 2.2685 - prec: 0.0014 - rec: 0.4329 - val_auc: 0.4969 - val_loss: 0.6413 - val_prec: 0.0028 - val_rec: 0.3750 - learning_rate: 4.5534e-05
# Epoch 2/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - auc: 0.5097 - loss: 1.5300 - prec: 0.0015 - rec: 0.4846 - val_auc: 0.9026 - val_loss: 0.6975 - val_prec: 0.0047 - val_rec: 1.0000 - learning_rate: 4.5534e-05
# Epoch 3/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.4935 - loss: 1.5803 - prec: 0.0018 - rec: 0.5469 - val_auc: 0.9639 - val_loss: 0.7342 - val_prec: 0.0041 - val_rec: 1.0000 - learning_rate: 4.5534e-05
# Epoch 4/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.6838 - loss: 1.0727 - prec: 0.0022 - rec: 0.6686 - val_auc: 0.9639 - val_loss: 0.7549 - val_prec: 0.0040 - val_rec: 1.0000 - learning_rate: 4.5534e-05
# Epoch 5/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.6030 - loss: 1.0020 - prec: 0.0019 - rec: 0.6047 - val_auc: 0.9610 - val_loss: 0.7713 - val_prec: 0.0040 - val_rec: 1.0000 - learning_rate: 2.2767e-05
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 1/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 9s 95ms/step - auc: 0.7197 - loss: 0.7815 - prec: 0.0025 - rec: 0.7492 - val_auc: 0.8759 - val_loss: 0.5874 - val_prec: 0.0072 - val_rec: 0.8333 - learning_rate: 0.0016
# Epoch 2/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9598 - loss: 0.3632 - prec: 0.0046 - rec: 0.9592 - val_auc: 0.9969 - val_loss: 0.4223 - val_prec: 0.0278 - val_rec: 1.0000 - learning_rate: 0.0016
# Epoch 3/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9606 - loss: 0.2830 - prec: 0.0081 - rec: 0.9592 - val_auc: 0.9986 - val_loss: 0.3128 - val_prec: 0.0522 - val_rec: 1.0000 - learning_rate: 0.0016
# Epoch 4/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9606 - loss: 0.2344 - prec: 0.0128 - rec: 0.9354 - val_auc: 0.9995 - val_loss: 0.2390 - val_prec: 0.0822 - val_rec: 1.0000 - learning_rate: 0.0016
# Epoch 5/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9762 - loss: 0.1714 - prec: 0.0209 - rec: 0.9709 - val_auc: 0.9996 - val_loss: 0.1814 - val_prec: 0.1034 - val_rec: 1.0000 - learning_rate: 0.0016
# Epoch 6/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9768 - loss: 0.1426 - prec: 0.0286 - rec: 0.9725 - val_auc: 0.9998 - val_loss: 0.1645 - val_prec: 0.1132 - val_rec: 1.0000 - learning_rate: 7.8700e-04
# Epoch 7/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9770 - loss: 0.1318 - prec: 0.0369 - rec: 0.9725 - val_auc: 0.9999 - val_loss: 0.1502 - val_prec: 0.1176 - val_rec: 1.0000 - learning_rate: 7.8700e-04
# Epoch 8/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9736 - loss: 0.1338 - prec: 0.0369 - rec: 0.9592 - val_auc: 0.9998 - val_loss: 0.1443 - val_prec: 0.1200 - val_rec: 1.0000 - learning_rate: 3.9350e-04
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 1/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 8s 81ms/step - auc: 0.9011 - loss: 0.5141 - prec: 0.0037 - rec: 0.9139 - val_auc: 0.9984 - val_loss: 0.5839 - val_prec: 0.0127 - val_rec: 1.0000 - learning_rate: 0.0016
# Epoch 2/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - auc: 0.9626 - loss: 0.3388 - prec: 0.0068 - rec: 0.9565 - val_auc: 0.9980 - val_loss: 0.3986 - val_prec: 0.0386 - val_rec: 1.0000 - learning_rate: 0.0016
# Epoch 3/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9805 - loss: 0.2519 - prec: 0.0109 - rec: 0.9565 - val_auc: 0.9980 - val_loss: 0.3267 - val_prec: 0.0602 - val_rec: 1.0000 - learning_rate: 7.8700e-04
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Epoch 1/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 9s 100ms/step - auc: 0.3535 - loss: 1.5692 - prec: 0.0013 - rec: 0.4255 - val_auc: 0.8119 - val_loss: 0.7481 - val_prec: 0.0036 - val_rec: 0.8333 - learning_rate: 4.0151e-04
# Epoch 2/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7181 - loss: 0.6979 - prec: 0.0023 - rec: 0.7108 - val_auc: 0.8353 - val_loss: 0.7339 - val_prec: 0.0038 - val_rec: 0.8333 - learning_rate: 4.0151e-04
# Epoch 3/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7958 - loss: 0.5792 - prec: 0.0026 - rec: 0.7458 - val_auc: 0.8410 - val_loss: 0.6999 - val_prec: 0.0043 - val_rec: 0.8333 - learning_rate: 4.0151e-04
# Epoch 4/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8767 - loss: 0.4879 - prec: 0.0033 - rec: 0.8628 - val_auc: 0.8576 - val_loss: 0.6591 - val_prec: 0.0050 - val_rec: 0.8333 - learning_rate: 4.0151e-04
# Epoch 5/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8787 - loss: 0.4618 - prec: 0.0037 - rec: 0.8321 - val_auc: 0.8995 - val_loss: 0.6175 - val_prec: 0.0058 - val_rec: 0.8333 - learning_rate: 4.0151e-04
# Epoch 6/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9320 - loss: 0.3906 - prec: 0.0046 - rec: 0.8949 - val_auc: 0.9330 - val_loss: 0.5741 - val_prec: 0.0068 - val_rec: 0.8333 - learning_rate: 4.0151e-04
# Epoch 7/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9338 - loss: 0.3702 - prec: 0.0055 - rec: 0.9137 - val_auc: 0.9622 - val_loss: 0.5321 - val_prec: 0.0080 - val_rec: 0.8333 - learning_rate: 4.0151e-04
# Epoch 8/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9664 - loss: 0.3226 - prec: 0.0068 - rec: 0.9725 - val_auc: 0.9760 - val_loss: 0.4897 - val_prec: 0.0121 - val_rec: 1.0000 - learning_rate: 4.0151e-04
# Epoch 9/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9514 - loss: 0.3212 - prec: 0.0073 - rec: 0.8887 - val_auc: 0.9879 - val_loss: 0.4514 - val_prec: 0.0149 - val_rec: 1.0000 - learning_rate: 4.0151e-04
# Epoch 10/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9733 - loss: 0.2717 - prec: 0.0097 - rec: 0.9583 - val_auc: 0.9916 - val_loss: 0.4149 - val_prec: 0.0195 - val_rec: 1.0000 - learning_rate: 4.0151e-04
# Epoch 11/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9759 - loss: 0.2537 - prec: 0.0120 - rec: 0.9725 - val_auc: 0.9940 - val_loss: 0.3810 - val_prec: 0.0254 - val_rec: 1.0000 - learning_rate: 4.0151e-04
# Epoch 12/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9490 - loss: 0.2698 - prec: 0.0136 - rec: 0.9049 - val_auc: 0.9964 - val_loss: 0.3518 - val_prec: 0.0308 - val_rec: 1.0000 - learning_rate: 4.0151e-04
# Epoch 13/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9746 - loss: 0.2234 - prec: 0.0167 - rec: 0.9583 - val_auc: 0.9970 - val_loss: 0.3251 - val_prec: 0.0390 - val_rec: 1.0000 - learning_rate: 4.0151e-04
# Epoch 14/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9764 - loss: 0.2109 - prec: 0.0198 - rec: 0.9725 - val_auc: 0.9974 - val_loss: 0.2994 - val_prec: 0.0462 - val_rec: 1.0000 - learning_rate: 4.0151e-04
# Epoch 15/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9769 - loss: 0.1941 - prec: 0.0243 - rec: 0.9725 - val_auc: 0.9979 - val_loss: 0.2777 - val_prec: 0.0566 - val_rec: 1.0000 - learning_rate: 4.0151e-04
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 1/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - auc: 0.0979 - loss: 3.2551 - prec: 2.8525e-04 - rec: 0.0929 - val_auc: 0.5671 - val_loss: 0.6652 - val_prec: 0.0042 - val_rec: 0.6250 - learning_rate: 4.0151e-04
# Epoch 2/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - auc: 0.6453 - loss: 0.9221 - prec: 0.0020 - rec: 0.6881 - val_auc: 0.9569 - val_loss: 0.6963 - val_prec: 0.0059 - val_rec: 1.0000 - learning_rate: 4.0151e-04
# Epoch 3/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8576 - loss: 0.6213 - prec: 0.0026 - rec: 0.8635 - val_auc: 0.9604 - val_loss: 0.6981 - val_prec: 0.0060 - val_rec: 1.0000 - learning_rate: 4.0151e-04
# Epoch 4/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9499 - loss: 0.4718 - prec: 0.0032 - rec: 0.9727 - val_auc: 0.9627 - val_loss: 0.6815 - val_prec: 0.0064 - val_rec: 1.0000 - learning_rate: 4.0151e-04
# Epoch 5/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9459 - loss: 0.4493 - prec: 0.0035 - rec: 0.9446 - val_auc: 0.9658 - val_loss: 0.6519 - val_prec: 0.0071 - val_rec: 1.0000 - learning_rate: 4.0151e-04
# Epoch 6/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9646 - loss: 0.4118 - prec: 0.0041 - rec: 0.9886 - val_auc: 0.9701 - val_loss: 0.6164 - val_prec: 0.0083 - val_rec: 1.0000 - learning_rate: 4.0151e-04
# Epoch 7/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9638 - loss: 0.3851 - prec: 0.0047 - rec: 0.9620 - val_auc: 0.9749 - val_loss: 0.5792 - val_prec: 0.0098 - val_rec: 1.0000 - learning_rate: 4.0151e-04
# Epoch 8/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9181 - loss: 0.4011 - prec: 0.0052 - rec: 0.9010 - val_auc: 0.9784 - val_loss: 0.5410 - val_prec: 0.0123 - val_rec: 1.0000 - learning_rate: 4.0151e-04
# Epoch 9/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.9735 - loss: 0.3300 - prec: 0.0068 - rec: 0.9620 - val_auc: 0.9804 - val_loss: 0.5033 - val_prec: 0.0161 - val_rec: 1.0000 - learning_rate: 4.0151e-04
# Epoch 10/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - auc: 0.9776 - loss: 0.3217 - prec: 0.0086 - rec: 0.9620 - val_auc: 0.9832 - val_loss: 0.4675 - val_prec: 0.0197 - val_rec: 0.8750 - learning_rate: 4.0151e-04
# Epoch 11/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.9806 - loss: 0.2963 - prec: 0.0111 - rec: 0.9886 - val_auc: 0.9834 - val_loss: 0.4350 - val_prec: 0.0266 - val_rec: 0.8750 - learning_rate: 4.0151e-04
# Epoch 12/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - auc: 0.9779 - loss: 0.2874 - prec: 0.0135 - rec: 0.9299 - val_auc: 0.9844 - val_loss: 0.4057 - val_prec: 0.0350 - val_rec: 0.8750 - learning_rate: 4.0151e-04
# Epoch 13/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.9797 - loss: 0.2611 - prec: 0.0174 - rec: 0.9565 - val_auc: 0.9842 - val_loss: 0.3789 - val_prec: 0.0470 - val_rec: 0.8750 - learning_rate: 4.0151e-04
# Epoch 14/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9837 - loss: 0.2714 - prec: 0.0212 - rec: 0.9299 - val_auc: 0.9846 - val_loss: 0.3667 - val_prec: 0.0519 - val_rec: 0.8750 - learning_rate: 2.0076e-04
# Epoch 15/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9874 - loss: 0.2397 - prec: 0.0236 - rec: 0.9527 - val_auc: 0.9858 - val_loss: 0.3550 - val_prec: 0.0569 - val_rec: 0.8750 - learning_rate: 2.0076e-04
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 1/15
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 12s 243ms/step - auc: 0.1549 - loss: 2.7022 - prec: 4.0423e-04 - rec: 0.1295 - val_auc: 0.0117 - val_loss: 0.7948 - val_prec: 0.0000e+00 - val_rec: 0.0000e+00 - learning_rate: 5.2626e-05
# Epoch 2/15
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.3686 - loss: 2.1139 - prec: 0.0011 - rec: 0.3878 - val_auc: 0.0188 - val_loss: 0.8333 - val_prec: 0.0000e+00 - val_rec: 0.0000e+00 - learning_rate: 5.2626e-05
# Epoch 3/15
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.2843 - loss: 2.0064 - prec: 9.7262e-04 - rec: 0.3250 - val_auc: 0.0417 - val_loss: 0.8655 - val_prec: 0.0000e+00 - val_rec: 0.0000e+00 - learning_rate: 5.2626e-05
# Epoch 4/15
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.3085 - loss: 1.6875 - prec: 9.7022e-04 - rec: 0.3117 - val_auc: 0.1188 - val_loss: 0.8894 - val_prec: 5.2938e-04 - val_rec: 0.1667 - learning_rate: 5.2626e-05
# Epoch 5/15
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.4353 - loss: 1.2739 - prec: 0.0012 - rec: 0.3901 - val_auc: 0.2162 - val_loss: 0.9074 - val_prec: 5.2715e-04 - val_rec: 0.1667 - learning_rate: 5.2626e-05
# Epoch 6/15
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.5829 - loss: 1.1155 - prec: 0.0018 - rec: 0.5940 - val_auc: 0.3187 - val_loss: 0.9182 - val_prec: 0.0011 - val_rec: 0.3333 - learning_rate: 5.2626e-05
# Epoch 7/15
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.5270 - loss: 1.0836 - prec: 0.0015 - rec: 0.4692 - val_auc: 0.4241 - val_loss: 0.9246 - val_prec: 0.0011 - val_rec: 0.3333 - learning_rate: 5.2626e-05
# Epoch 8/15
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - auc: 0.6754 - loss: 0.8953 - prec: 0.0023 - rec: 0.7501 - val_auc: 0.5269 - val_loss: 0.9270 - val_prec: 0.0023 - val_rec: 0.6667 - learning_rate: 5.2626e-05
# Epoch 9/15
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.6113 - loss: 0.8413 - prec: 0.0017 - rec: 0.5219 - val_auc: 0.5991 - val_loss: 0.9275 - val_prec: 0.0023 - val_rec: 0.6667 - learning_rate: 5.2626e-05
# Epoch 10/15
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.6258 - loss: 0.9368 - prec: 0.0020 - rec: 0.6373 - val_auc: 0.6493 - val_loss: 0.9261 - val_prec: 0.0024 - val_rec: 0.6667 - learning_rate: 5.2626e-05
# Epoch 11/15
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - auc: 0.6726 - loss: 0.9998 - prec: 0.0020 - rec: 0.6617 - val_auc: 0.7035 - val_loss: 0.9246 - val_prec: 0.0024 - val_rec: 0.6667 - learning_rate: 5.2626e-05
# Epoch 12/15
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.7502 - loss: 0.7941 - prec: 0.0023 - rec: 0.7320 - val_auc: 0.7795 - val_loss: 0.9213 - val_prec: 0.0031 - val_rec: 0.8333 - learning_rate: 5.2626e-05
# Epoch 13/15
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.7525 - loss: 0.7547 - prec: 0.0024 - rec: 0.7730 - val_auc: 0.8486 - val_loss: 0.9176 - val_prec: 0.0038 - val_rec: 1.0000 - learning_rate: 5.2626e-05
# Epoch 14/15
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.8098 - loss: 0.7190 - prec: 0.0026 - rec: 0.8118 - val_auc: 0.8911 - val_loss: 0.9146 - val_prec: 0.0038 - val_rec: 1.0000 - learning_rate: 5.2626e-05
# Epoch 15/15
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.8892 - loss: 0.6187 - prec: 0.0029 - rec: 0.9066 - val_auc: 0.9104 - val_loss: 0.9117 - val_prec: 0.0039 - val_rec: 1.0000 - learning_rate: 5.2626e-05
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 1/15
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 14s 234ms/step - auc: 0.4270 - loss: 1.2091 - prec: 0.0012 - rec: 0.3174 - val_auc: 0.7275 - val_loss: 0.9807 - val_prec: 0.0029 - val_rec: 0.8750 - learning_rate: 5.2626e-05
# Epoch 2/15
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - auc: 0.6058 - loss: 0.9639 - prec: 0.0022 - rec: 0.5707 - val_auc: 0.7245 - val_loss: 0.9178 - val_prec: 0.0034 - val_rec: 0.7500 - learning_rate: 5.2626e-05
# Epoch 3/15
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.7176 - loss: 0.8297 - prec: 0.0027 - rec: 0.7030 - val_auc: 0.7066 - val_loss: 0.8847 - val_prec: 0.0041 - val_rec: 0.7500 - learning_rate: 2.6313e-05
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 1/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 10s 97ms/step - auc: 0.5382 - loss: 1.0828 - prec: 0.0018 - rec: 0.5216 - val_auc: 0.9736 - val_loss: 0.7091 - val_prec: 0.0066 - val_rec: 1.0000 - learning_rate: 9.7240e-04
# Epoch 2/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9713 - loss: 0.4376 - prec: 0.0043 - rec: 0.9815 - val_auc: 0.9949 - val_loss: 0.5558 - val_prec: 0.0189 - val_rec: 1.0000 - learning_rate: 9.7240e-04
# Epoch 3/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9776 - loss: 0.3508 - prec: 0.0070 - rec: 0.9815 - val_auc: 0.9983 - val_loss: 0.4421 - val_prec: 0.0469 - val_rec: 1.0000 - learning_rate: 9.7240e-04
# Epoch 4/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9799 - loss: 0.2848 - prec: 0.0138 - rec: 0.9815 - val_auc: 0.9993 - val_loss: 0.3579 - val_prec: 0.0882 - val_rec: 1.0000 - learning_rate: 9.7240e-04
# Epoch 5/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9808 - loss: 0.2354 - prec: 0.0287 - rec: 0.9815 - val_auc: 0.9995 - val_loss: 0.2931 - val_prec: 0.1765 - val_rec: 1.0000 - learning_rate: 9.7240e-04
# Epoch 6/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9811 - loss: 0.1984 - prec: 0.0583 - rec: 0.9815 - val_auc: 0.9997 - val_loss: 0.2438 - val_prec: 0.2069 - val_rec: 1.0000 - learning_rate: 9.7240e-04
# Epoch 7/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9812 - loss: 0.1704 - prec: 0.1065 - rec: 0.9815 - val_auc: 0.9998 - val_loss: 0.2065 - val_prec: 0.2727 - val_rec: 1.0000 - learning_rate: 9.7240e-04
# Epoch 8/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9812 - loss: 0.1492 - prec: 0.1557 - rec: 0.9815 - val_auc: 0.9999 - val_loss: 0.1772 - val_prec: 0.3529 - val_rec: 1.0000 - learning_rate: 9.7240e-04
# Epoch 9/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9813 - loss: 0.1339 - prec: 0.1997 - rec: 0.9815 - val_auc: 0.9999 - val_loss: 0.1660 - val_prec: 0.3750 - val_rec: 1.0000 - learning_rate: 4.8620e-04
# Epoch 10/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9813 - loss: 0.1266 - prec: 0.2304 - rec: 0.9815 - val_auc: 0.9999 - val_loss: 0.1554 - val_prec: 0.4286 - val_rec: 1.0000 - learning_rate: 4.8620e-04
# Epoch 11/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9813 - loss: 0.1208 - prec: 0.2579 - rec: 0.9815 - val_auc: 0.9999 - val_loss: 0.1515 - val_prec: 0.4286 - val_rec: 1.0000 - learning_rate: 2.4310e-04
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 1/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 9s 89ms/step - auc: 0.6064 - loss: 1.1723 - prec: 0.0020 - rec: 0.6536 - val_auc: 0.8802 - val_loss: 0.6222 - val_prec: 0.0101 - val_rec: 0.8750 - learning_rate: 9.7240e-04
# Epoch 2/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - auc: 0.9288 - loss: 0.4990 - prec: 0.0036 - rec: 0.9353 - val_auc: 0.8829 - val_loss: 0.5955 - val_prec: 0.0127 - val_rec: 0.8750 - learning_rate: 9.7240e-04
# Epoch 3/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9745 - loss: 0.3874 - prec: 0.0057 - rec: 0.9620 - val_auc: 0.8890 - val_loss: 0.5200 - val_prec: 0.0224 - val_rec: 0.8750 - learning_rate: 9.7240e-04
# Epoch 4/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9936 - loss: 0.3142 - prec: 0.0106 - rec: 0.9886 - val_auc: 0.9007 - val_loss: 0.4376 - val_prec: 0.0395 - val_rec: 0.8750 - learning_rate: 9.7240e-04
# Epoch 5/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9975 - loss: 0.2614 - prec: 0.0201 - rec: 0.9886 - val_auc: 0.9237 - val_loss: 0.3652 - val_prec: 0.0680 - val_rec: 0.8750 - learning_rate: 9.7240e-04
# Epoch 6/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - auc: 0.9989 - loss: 0.2227 - prec: 0.0366 - rec: 0.9886 - val_auc: 0.9415 - val_loss: 0.3079 - val_prec: 0.1000 - val_rec: 0.8750 - learning_rate: 9.7240e-04
# Epoch 7/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - auc: 0.9995 - loss: 0.1919 - prec: 0.0616 - rec: 1.0000 - val_auc: 0.9583 - val_loss: 0.2630 - val_prec: 0.1400 - val_rec: 0.8750 - learning_rate: 9.7240e-04
# Epoch 8/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.9997 - loss: 0.1682 - prec: 0.0917 - rec: 1.0000 - val_auc: 0.9743 - val_loss: 0.2299 - val_prec: 0.1628 - val_rec: 0.8750 - learning_rate: 9.7240e-04
# Epoch 9/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - auc: 0.9999 - loss: 0.1491 - prec: 0.1238 - rec: 1.0000 - val_auc: 0.9785 - val_loss: 0.2021 - val_prec: 0.1944 - val_rec: 0.8750 - learning_rate: 9.7240e-04
# Epoch 10/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - auc: 0.9999 - loss: 0.1343 - prec: 0.1632 - rec: 1.0000 - val_auc: 0.9850 - val_loss: 0.1826 - val_prec: 0.1892 - val_rec: 0.8750 - learning_rate: 9.7240e-04
# Epoch 11/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.9999 - loss: 0.1224 - prec: 0.1945 - rec: 1.0000 - val_auc: 0.9875 - val_loss: 0.1645 - val_prec: 0.2500 - val_rec: 0.8750 - learning_rate: 9.7240e-04
# Epoch 12/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 1.0000 - loss: 0.1124 - prec: 0.2227 - rec: 1.0000 - val_auc: 0.9887 - val_loss: 0.1504 - val_prec: 0.2692 - val_rec: 0.8750 - learning_rate: 9.7240e-04
# Epoch 13/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 1.0000 - loss: 0.1044 - prec: 0.2389 - rec: 1.0000 - val_auc: 0.9908 - val_loss: 0.1384 - val_prec: 0.2800 - val_rec: 0.8750 - learning_rate: 9.7240e-04
# Epoch 14/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 1.0000 - loss: 0.0978 - prec: 0.2724 - rec: 1.0000 - val_auc: 0.9915 - val_loss: 0.1304 - val_prec: 0.2800 - val_rec: 0.8750 - learning_rate: 9.7240e-04
# Epoch 15/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 1.0000 - loss: 0.0923 - prec: 0.2799 - rec: 1.0000 - val_auc: 0.9915 - val_loss: 0.1219 - val_prec: 0.2800 - val_rec: 0.8750 - learning_rate: 9.7240e-04
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 1/20
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - auc: 0.9060 - loss: 0.4593 - prec: 0.0036 - rec: 0.8946 - val_auc: 0.9563 - val_loss: 0.5221 - val_prec: 0.0159 - val_rec: 0.9286 - learning_rate: 5.0214e-04
# Epoch 2/20
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - auc: 0.9686 - loss: 0.2886 - prec: 0.0088 - rec: 0.9523 - val_auc: 0.9817 - val_loss: 0.3662 - val_prec: 0.0512 - val_rec: 0.9286 - learning_rate: 5.0214e-04
# Epoch 3/20
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9858 - loss: 0.2057 - prec: 0.0246 - rec: 0.9869 - val_auc: 0.9890 - val_loss: 0.2668 - val_prec: 0.0850 - val_rec: 0.9286 - learning_rate: 5.0214e-04
# Epoch 4/20
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - auc: 0.9878 - loss: 0.1550 - prec: 0.0481 - rec: 0.9869 - val_auc: 0.9907 - val_loss: 0.2006 - val_prec: 0.1182 - val_rec: 0.9286 - learning_rate: 5.0214e-04
# Epoch 5/20
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9888 - loss: 0.1215 - prec: 0.0702 - rec: 0.9880 - val_auc: 0.9906 - val_loss: 0.1554 - val_prec: 0.1398 - val_rec: 0.9286 - learning_rate: 5.0214e-04
# Epoch 6/20
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - auc: 0.9897 - loss: 0.0985 - prec: 0.0895 - rec: 0.9880 - val_auc: 0.9899 - val_loss: 0.1376 - val_prec: 0.1529 - val_rec: 0.9286 - learning_rate: 2.5107e-04
#
# === Random Search: melhores hiperparâmetros ===
# {'clf__batch_size': 512, 'clf__epochs': 20, 'clf__model__dropout': 0.0, 'clf__model__hidden_layers': 1, 'clf__model__l2': 0.0001, 'clf__model__learning_rate': np.float64(0.0005021425736625638), 'clf__model__units': 73}
# Melhor AUC-ROC (CV, subset): 0.9811

# %% [markdown]
# ## Grid Search

# %%
from itertools import product
from sklearn.model_selection import StratifiedKFold, StratifiedShuffleSplit

early_stop_search = keras.callbacks.EarlyStopping(
    monitor="val_auc", patience=3, mode="max", restore_best_weights=True, min_delta=1e-4
)
reduce_lr_search = keras.callbacks.ReduceLROnPlateau(
    monitor="val_auc", factor=0.5, patience=1, mode="max", min_lr=1e-6
)

def make_pipe_search():
    return Pipeline([
        ("preprocess", preprocess),
        ("clf", KerasClassifier(
            model=build_mlp,
            verbose=0,
            callbacks=[early_stop_search, reduce_lr_search],
        )),
    ])

try:
    best_rs = rs.best_params_
except NameError:
    # fallback se RS não rodou
    best_rs = {
        "clf__model__hidden_layers": 2,
        "clf__model__units": 64,
        "clf__model__dropout": 0.2,
        "clf__model__l2": 1e-4,
        "clf__model__learning_rate": 1e-3,
        "clf__batch_size": 512,
        "clf__epochs": 20,
    }

def around_units(u):
    c = int(u); return sorted(set([max(16, c//2), c, min(256, c*2)]))
def around_float(v, low=1e-5, high=1e-2):
    return sorted(set([max(low, v/2), v, min(high, v*2)]))

param_grid = {
    "clf__model__hidden_layers": [max(1, best_rs["clf__model__hidden_layers"]-1),
                                  best_rs["clf__model__hidden_layers"],
                                  min(4, best_rs["clf__model__hidden_layers"]+1)],
    "clf__model__units": around_units(best_rs["clf__model__units"]),
    "clf__model__dropout": [max(0.0, best_rs["clf__model__dropout"]-0.1),
                            best_rs["clf__model__dropout"],
                            min(0.5, best_rs["clf__model__dropout"]+0.1)],
    "clf__model__l2": sorted(set([
        best_rs["clf__model__l2"]/10 if best_rs["clf__model__l2"]>0 else 0.0,
        best_rs["clf__model__l2"],
        best_rs["clf__model__l2"]*10 if best_rs["clf__model__l2"]>0 else 1e-5
    ])),
    "clf__model__learning_rate": around_float(best_rs["clf__model__learning_rate"]),
    "clf__batch_size": sorted(set([max(256, best_rs["clf__batch_size"]//2),
                                   best_rs["clf__batch_size"],
                                   min(2048, best_rs["clf__batch_size"]*2)])),
    "clf__epochs": sorted(set([max(12, best_rs["clf__epochs"]-5),
                               best_rs["clf__epochs"],
                               min(30, best_rs["clf__epochs"]+5)])),
}

keys = list(param_grid.keys())
grid_list = list(product(*[param_grid[k] for k in keys]))

MAX_COMBOS = 12
rng = np.random.default_rng(SEED)
if len(grid_list) > MAX_COMBOS:
    sel = rng.choice(len(grid_list), size=MAX_COMBOS, replace=False)
    grid_list = [grid_list[i] for i in sel]

skf = StratifiedKFold(n_splits=2, shuffle=True, random_state=SEED)

best_auc = -np.inf
best_params_gs = None

from sklearn.metrics import roc_auc_score

def _safe_proba(pipe, X):
    try:
        p = pipe.predict_proba(X)
    except Exception:
        Xt = pipe.named_steps["preprocess"].transform(X)
        p = pipe.named_steps["clf"].predict_proba(Xt)
    p = np.asarray(p)
    return p[:,1] if p.ndim==2 and p.shape[1]==2 else p.ravel()

print(f"Total de combinações avaliadas no grid manual: {len(grid_list)}")
for i, combo in enumerate(grid_list, 1):
    params = dict(zip(keys, combo))
    aucs = []
    for tr_idx, va_idx in skf.split(X_rs, y_rs):
        X_tr, X_va = X_rs.iloc[tr_idx], X_rs.iloc[va_idx]
        y_tr, y_va = y_rs.iloc[tr_idx], y_rs.iloc[va_idx]

        pipe = make_pipe_search()
        pipe.set_params(**params)
        pipe.fit(X_tr, y_tr, **{**FIT_KW, "clf__validation_split": 0.1})

        y_proba = _safe_proba(pipe, X_va)
        aucs.append(roc_auc_score(y_va, y_proba))

    mean_auc = float(np.mean(aucs))
    print(f"[{i}/{len(grid_list)}] AUC(mean)={mean_auc:.4f} | params={params}")

    if mean_auc > best_auc:
        best_auc = mean_auc
        best_params_gs = params

print("\n=== Grid Search (manual): melhores hiperparâmetros ===")
print(best_params_gs)
print(f"Melhor AUC-ROC (CV, subset): {best_auc:.4f}")
# Out:
# Total de combinações avaliadas no grid manual: 12
# [1/12] AUC(mean)=0.9856 | params={'clf__model__hidden_layers': 1, 'clf__model__units': 36, 'clf__model__dropout': 0.1, 'clf__model__l2': 0.001, 'clf__model__learning_rate': np.float64(0.0005021425736625638), 'clf__batch_size': 256, 'clf__epochs': 25}
# [2/12] AUC(mean)=0.9752 | params={'clf__model__hidden_layers': 1, 'clf__model__units': 36, 'clf__model__dropout': 0.1, 'clf__model__l2': 1e-05, 'clf__model__learning_rate': np.float64(0.0010042851473251275), 'clf__batch_size': 1024, 'clf__epochs': 20}
# [3/12] AUC(mean)=0.9734 | params={'clf__model__hidden_layers': 2, 'clf__model__units': 36, 'clf__model__dropout': 0.1, 'clf__model__l2': 0.001, 'clf__model__learning_rate': np.float64(0.0005021425736625638), 'clf__batch_size': 256, 'clf__epochs': 20}
# [4/12] AUC(mean)=0.9405 | params={'clf__model__hidden_layers': 1, 'clf__model__units': 73, 'clf__model__dropout': 0.1, 'clf__model__l2': 1e-05, 'clf__model__learning_rate': np.float64(0.0005021425736625638), 'clf__batch_size': 1024, 'clf__epochs': 20}
# [5/12] AUC(mean)=0.9718 | params={'clf__model__hidden_layers': 1, 'clf__model__units': 146, 'clf__model__dropout': 0.1, 'clf__model__l2': 0.0001, 'clf__model__learning_rate': np.float64(0.0010042851473251275), 'clf__batch_size': 512, 'clf__epochs': 15}
# [6/12] AUC(mean)=0.9665 | params={'clf__model__hidden_layers': 2, 'clf__model__units': 73, 'clf__model__dropout': 0.1, 'clf__model__l2': 1e-05, 'clf__model__learning_rate': np.float64(0.0005021425736625638), 'clf__batch_size': 256, 'clf__epochs': 15}
# [7/12] AUC(mean)=0.9444 | params={'clf__model__hidden_layers': 1, 'clf__model__units': 36, 'clf__model__dropout': 0.1, 'clf__model__l2': 0.0001, 'clf__model__learning_rate': np.float64(0.0002510712868312819), 'clf__batch_size': 512, 'clf__epochs': 25}
# [8/12] AUC(mean)=0.9684 | params={'clf__model__hidden_layers': 1, 'clf__model__units': 36, 'clf__model__dropout': 0.1, 'clf__model__l2': 0.0001, 'clf__model__learning_rate': np.float64(0.0010042851473251275), 'clf__batch_size': 1024, 'clf__epochs': 20}
# [9/12] AUC(mean)=0.9719 | params={'clf__model__hidden_layers': 1, 'clf__model__units': 36, 'clf__model__dropout': 0.1, 'clf__model__l2': 0.0001, 'clf__model__learning_rate': np.float64(0.0005021425736625638), 'clf__batch_size': 1024, 'clf__epochs': 20}
# [10/12] AUC(mean)=0.9415 | params={'clf__model__hidden_layers': 2, 'clf__model__units': 36, 'clf__model__dropout': 0.0, 'clf__model__l2': 0.001, 'clf__model__learning_rate': np.float64(0.0005021425736625638), 'clf__batch_size': 256, 'clf__epochs': 20}
# [11/12] AUC(mean)=0.9867 | params={'clf__model__hidden_layers': 2, 'clf__model__units': 146, 'clf__model__dropout': 0.1, 'clf__model__l2': 0.0001, 'clf__model__learning_rate': np.float64(0.0002510712868312819), 'clf__batch_size': 256, 'clf__epochs': 15}
# [12/12] AUC(mean)=0.9682 | params={'clf__model__hidden_layers': 1, 'clf__model__units': 73, 'clf__model__dropout': 0.1, 'clf__model__l2': 0.0001, 'clf__model__learning_rate': np.float64(0.0002510712868312819), 'clf__batch_size': 1024, 'clf__epochs': 25}
#
# === Grid Search (manual): melhores hiperparâmetros ===
# {'clf__model__hidden_layers': 2, 'clf__model__units': 146, 'clf__model__dropout': 0.1, 'clf__model__l2': 0.0001, 'clf__model__learning_rate': np.float64(0.0002510712868312819), 'clf__batch_size': 256, 'clf__epochs': 15}
# Melhor AUC-ROC (CV, subset): 0.9867

# %% [markdown]
# ## Avaliação final - Comparação e Análise

# %%
# callbacks "normais" para o treino final
early_stop_final = keras.callbacks.EarlyStopping(
    monitor="val_auc", patience=5, mode="max", restore_best_weights=True, min_delta=1e-4
)
reduce_lr_final = keras.callbacks.ReduceLROnPlateau(
    monitor="val_auc", factor=0.5, patience=2, mode="max", min_lr=1e-6
)

# monta o pipeline final com os melhores params
best_pipe = Pipeline([
    ("preprocess", preprocess),
    ("clf", KerasClassifier(
        model=build_mlp,
        verbose=0,
        callbacks=[early_stop_final, reduce_lr_final],
    )),
])
best_pipe.set_params(**best_params_gs)

# treino final no TREINO COMPLETO
best_pipe.fit(X_train, y_train, **FIT_KW)

# métricas no TESTE
tuned_metrics = evaluate(best_pipe, X_test, y_test, name="Otimizado (Grid manual)")

# comparação
comparison = pd.DataFrame([baseline_metrics, tuned_metrics]).set_index("model")
print("\n=== Comparação (Baseline vs Otimizado) ===")
display(comparison)

# ganhos absolutos
improve = {
    "AUC-ROC": tuned_metrics["auc"] - baseline_metrics["auc"],
    "Precisão": tuned_metrics["precision"] - baseline_metrics["precision"],
    "Recall": tuned_metrics["recall"] - baseline_metrics["recall"],
    "F1-score": tuned_metrics["f1"] - baseline_metrics["f1"],
}
print("\n=== Ganho (Otimizado - Baseline) ===")
for k, v in improve.items():
    print(f"{k}: {v:+.4f}")
# Out:
# [Aviso] Fallback do predict_proba do Pipeline → estimador direto (AttributeError: 'super' object has no attribute '__sklearn_tags__')
#
# === Otimizado (Grid manual) ===
# AUC-ROC : 0.9756
# Precisão: 0.0594
# Recall  : 0.9286
# F1-score: 0.1116
#
# Matriz de confusão (verdadeiro x predito):
#  [[55422  1442]
#  [    7    91]]
#
# Relatório de classificação:
#                precision    recall  f1-score   support
#
#            0     0.9999    0.9746    0.9871     56864
#            1     0.0594    0.9286    0.1116        98
#
#     accuracy                         0.9746     56962
#    macro avg     0.5296    0.9516    0.5493     56962
# weighted avg     0.9983    0.9746    0.9856     56962
# === Comparação (Baseline vs Otimizado) ===
#                               auc  precision    recall        f1
# model
# Baseline                 0.976104   0.050886  0.908163  0.096372
# Otimizado (Grid manual)  0.975587   0.059361  0.928571  0.111588
# === Ganho (Otimizado - Baseline) ===
# AUC-ROC: -0.0005
# Precisão: +0.0085
# Recall: +0.0204
# F1-score: +0.0152

# %% [markdown]
# ## Análise do modelo otimizado (Random + Grid)
#
# **Melhores hiperparâmetros encontrados**
#
# * **Random Search (subset, CV)** → melhor AUC(CV) ≈ **0,9811**
#   `hidden_layers=1`, `units=73`, `dropout=0.0`, `l2=1e-4`, `learning_rate≈5,02e-4`, `batch_size=512`, `epochs=20`.
# * **Grid (manual, subset, refino local)** → melhor AUC(CV) ≈ **0,9867**
#   `hidden_layers=2`, `units=146`, `dropout=0,1`, `l2=1e-4`, `learning_rate≈2,51e-4`, `batch_size=256`, `epochs=15`.
#
# > O grid refinou o modelo para **mais capacidade** (2 camadas, 146 unidades), **LR menor** e **dropout leve** — combinação típica para **melhor generalização**.
#
# **Desempenho no TESTE (modelo otimizado)**
#
# * **AUC-ROC = 0,9756**, **Precisão = 0,0594**, **Recall = 0,9286**, **F1 = 0,1116**
# * **Matriz de confusão**: `TN=55.422`, `FP=1.442` (**FPR ≈ 2,54%**), `FN=7`, `TP=91`.

# %% [markdown]
# ## Comparação final (Otimizado × Baseline)
#
# | Métrica      | Baseline | Otimizado |            Δ (Otimizado – Baseline) |
# | ------------ | -------: | --------: | ----------------------------------: |
# | **AUC-ROC**  |   0,9761 |    0,9756 |                         **−0,0005** |
# | **Precisão** |   0,0509 |    0,0594 | **+0,0085** (≈ **+16,7%** relativo) |
# | **Recall**   |   0,9082 |    0,9286 |                         **+0,0204** |
# | **F1**       |   0,0964 |    0,1116 |                         **+0,0152** |
#
# Em números absolutos (na confusão):
#
# * **FP** caíram de **1.660 → 1.442 (−218 alertas falsos).
# * **FN** caíram de **9 → 7** (−2 fraudes perdidas).
# * **TP** subiram de **89 → 91**.
#
# ### Conclsuão
#
# * Houve um pequeno custo em AUC (−0,0005), mas ganhos claros em Precisão, Recall e F1 no conjunto de teste.
# * Na prática: o modelo otimizado acha mais fraudes (+2 TPs) **perdendo menos** (−2 FNs) e gera menos falsos positivos (−218), o que reduz retrabalho do time e aumenta o valor operacional do detector.
